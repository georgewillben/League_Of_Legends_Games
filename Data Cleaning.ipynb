# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import StratifiedShuffleSplit, train_test_split
from sklearn.impute import SimpleImputer

# %% [markdown]
# # 1.1 Load Data

# %%
df = pd.read_csv("high_diamond_ranked_10min.csv")
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 40 columns):
# gameId                          9879 non-null int64
# blueWins                        9879 non-null int64
# blueWardsPlaced                 9879 non-null int64
# blueWardsDestroyed              9879 non-null int64
# blueFirstBlood                  9879 non-null int64
# blueKills                       9879 non-null int64
# blueDeaths                      9879 non-null int64
# blueAssists                     9879 non-null int64
# blueEliteMonsters               9879 non-null int64
# blueDragons                     9879 non-null int64
# blueHeralds                     9879 non-null int64
# blueTowersDestroyed             9879 non-null int64
# blueTotalGold                   9879 non-null int64
# blueAvgLevel                    9879 non-null float64
# blueTotalExperience             9879 non-null int64
# blueTotalMinionsKilled          9879 non-null int64
# ...

# %% [markdown]
# # 2.1 Inspect Data for Errors

# %%
min_maxes = []
for col in df.columns:
    min_maxes.append({"Column":col, "Min":df[col].min(), "Max":df[col].max()})
    
pd.DataFrame(min_maxes)
# Out:
#                           Column           Max           Min
# 0                         gameId  4.527991e+09  4.295358e+09
# 1                       blueWins  1.000000e+00  0.000000e+00
# 2                blueWardsPlaced  2.500000e+02  5.000000e+00
# 3             blueWardsDestroyed  2.700000e+01  0.000000e+00
# 4                 blueFirstBlood  1.000000e+00  0.000000e+00
# 5                      blueKills  2.200000e+01  0.000000e+00
# 6                     blueDeaths  2.200000e+01  0.000000e+00
# 7                    blueAssists  2.900000e+01  0.000000e+00
# 8              blueEliteMonsters  2.000000e+00  0.000000e+00
# 9                    blueDragons  1.000000e+00  0.000000e+00
# 10                   blueHeralds  1.000000e+00  0.000000e+00
# 11           blueTowersDestroyed  4.000000e+00  0.000000e+00
# 12                 blueTotalGold  2.370100e+04  1.073000e+04
# 13                  blueAvgLevel  8.000000e+00  4.600000e+00
# ...

# %% [markdown]
# All these values seem to not be errors. There are no negative measurements

# %% [markdown]
# # 3.1 Inspect Distribution Of Columns

# %%
df.hist(figsize=(25, 15))
plt.tight_layout()
plt.show()

# %% [markdown]
# Many of the columns seem to be normally distributed.

# %% [markdown]
# # 3.2 See If Target Class Is Imbalanced

# %%
blue_win = df.blueWins.sum()
red_win = sum([1 if bluewin == 0 else 0 for bluewin in df.blueWins])

plt.figure(figsize=(15, 5))
bars = plt.bar(["Blue Wins", "Red Wins"], [blue_win, red_win])
plt.title("Wins by Colour")
bars[0].set_color("blue")
bars[1].set_color("red")
plt.show()
